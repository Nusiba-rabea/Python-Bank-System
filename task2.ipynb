# %% [markdown]
# 2-Write a program that prints the following exactly:
# Output:
# ***************
# Python Session 1
# ***************

# %%
print("***************")
print("Python Session 1")
print("***************")
# Out:
# ***************
# Python Session 1
# ***************

# %% [markdown]
# Print("Hello")
#
# print(Welcome)
#
# #Print my age
# print("20"

# %%
print("Hello")

print("Welcome")

# Print my age
print("20")
# Out:
# Hello
# Welcome
# 20

# %% [markdown]
# 4-Write a program that prints the following exactly:
# Output:
# I love python
# Space (  سطر فاضي
# Print(“I love python”)

# %%
print("I love python")
print("              ")
print("I love python")
# Out:
# I love python
#
# I love python
